# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from scipy.optimize import fsolve

# %%
def f(x):
    y = 2.0 * x**2 + 3.0*x - 10
    return y

x= np.linspace(-5,2)
print(x)
plt.plot(x,f(x))
plt.plot(x,np.zeros(len(x)))
plt.tick_params(direction='in')
plt.xlabel('X-Variable')
plt.ylabel('function f(x)')
plt.tight_layout()
# Out:
# [-5.         -4.85714286 -4.71428571 -4.57142857 -4.42857143 -4.28571429
#  -4.14285714 -4.         -3.85714286 -3.71428571 -3.57142857 -3.42857143
#  -3.28571429 -3.14285714 -3.         -2.85714286 -2.71428571 -2.57142857
#  -2.42857143 -2.28571429 -2.14285714 -2.         -1.85714286 -1.71428571
#  -1.57142857 -1.42857143 -1.28571429 -1.14285714 -1.         -0.85714286
#  -0.71428571 -0.57142857 -0.42857143 -0.28571429 -0.14285714  0.
#   0.14285714  0.28571429  0.42857143  0.57142857  0.71428571  0.85714286
#   1.          1.14285714  1.28571429  1.42857143  1.57142857  1.71428571
#   1.85714286  2.        ]

# %%
from IPython import get_ipython
get_ipython().magic('reset -sf')
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack
from scipy.optimize import curve_fit
import os
# %matplotlib notebook

ddir ='C:/Users/vijay/Downloads/Dong1/Dong1/'
A = np.loadtxt(ddir + 'p1'+ '.txt')
T1   = A[:,0]
ABS1 = ((A[:,1] - 0.50) / 0.2683) * 6894.76 + 70
DP1  = (((A[:,2] - 0.50) * 3447.38) - 6894.76 + 18)

# %%
plt.subplot(221)
plt.title('Pressure Spectra')
plt.plot(T1,ABS1,'r')
plt.subplot(222)
plt.title('Pressure Spectra')
plt.plot(T1,DP1,'g')
plt.subplot(223)
plt.title('Pressure Spectra')
plt.plot(T1,ABS1,'r')
plt.subplot(224)
plt.title('Pressure Spectra')
plt.plot(T1,DP1,'g')
plt.xlabel('Time(s)')
plt.ylabel('Pressure')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
#   File "<ipython-input-5-8e3c2f469c11>", line 1
#     conda install -c conda-forge/label/cf201901 ju
#                 ^
# SyntaxError: invalid syntax
